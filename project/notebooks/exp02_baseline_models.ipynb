# %% [markdown]
# ## exp02_baseline_models.ipynb -
# **Цель:**
# **Данные:** `data/train/`, `data/test/`
# **Подход:**

# %%
from src.constants import DATA_PATH
from src.data.loader import create_dataloaders
from src.models.baselines import prepare_flat_features, train_baseline_models
from sklearn.preprocessing import StandardScaler
from src.utils.experiment_logger import log_experiment

# Создаём DataLoader БЕЗ аугментаций для честного сравнения с классическими моделями
train_loader, val_loader, test_loader = create_dataloaders(DATA_PATH, batch_size=64)

X_train, y_train = prepare_flat_features(train_loader)
X_test, y_test = prepare_flat_features(test_loader)

# StandardScaler для логистической регрессии
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

baseline_results = train_baseline_models(X_train, y_train)

experiment_name = "baselines"
for model_name in baseline_results:
    model = baseline_results[model_name]
    preds = model.predict(X_test_scaled)

    training_cfg = {
        "experiment_name": experiment_name,
        "model_name": model_name,
        "scaler": "StandardScaler", 
        "augmentation": "None"
    }

    log_experiment(experiment_name, model_name, y_test, preds, training_cfg)
# Out:
# Подготовка данных (flattening + scaling)...
# Подготовка данных (flattening + scaling)...
#
# Обучение LogisticRegression...
# /mnt/d/AIE_course/Artificial_Intelligence_Engineering/project/project_venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Артефакт сохранен в /mnt/d/AIE_course/Artificial_Intelligence_Engineering/project/artifacts/checkpoints/LogisticRegression_baseline.pkl
#
# Обучение RandomForest...
# 2026/05/02 18:19:19 INFO mlflow.tracking.fluent: Experiment with name 'emotion_classification' does not exist. Creating a new experiment.
# Артефакт сохранен в /mnt/d/AIE_course/Artificial_Intelligence_Engineering/project/artifacts/checkpoints/RandomForest_baseline.pkl
# LogisticRegression | Acc=0.264 | F1=0.255 | Лог сохранен в MLflow и metrics.csv, конфиг записан в /mnt/d/AIE_course/Artificial_Intelligence_Engineering/project/configs/training_config_LogisticRegression.yaml
# RandomForest | Acc=0.244 | F1=0.202 | Лог сохранен в MLflow и metrics.csv, конфиг записан в /mnt/d/AIE_course/Artificial_Intelligence_Engineering/project/configs/training_config_RandomForest.yaml
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
